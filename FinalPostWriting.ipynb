# %%
#run dataframe creators for visuals
# %run Dataframecreators.ipynb
# Out:
# <ipython-input-31-91cc8dfe509e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_am['Swim Time Obj'] = df_am['Swim Time']/np.timedelta64(1, 'h')
# <ipython-input-31-91cc8dfe509e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_am['Bike Time Obj'] = df_am['Bike Time']/np.timedelta64(1, 'h')
# <ipython-input-31-91cc8dfe509e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_am['Run Time Obj'] = df_am['Run Time']/np.timedelta64(1, 'h')
# <ipython-input-31-91cc8dfe509e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_am['Total Time Obj'] = df_am['Total Time']/np.timedelta64(1, 'h')
# <ipython-input-31-a9b78da05327>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_am['experience'] = df_am.groupby('Name').size() # 3209 participants
# C:\Users\snoejovich\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-31-a9b78da05327>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_am['experience'] = df_am.groupby('Name')['Name'].transform('count')

# %%
#palette = sns.color_palette('gray', 2)

fig = plt.figure(constrained_layout=True, figsize=(8, 3))

plt.axvline(xmedian_swim, c='red')
plt.axvline(x25_swim, c='red')
plt.axvline(x75_swim, c='red')
sns.histplot(df_am, x='Swim Time DT', kde=False, bins = 10)

date_format = mpl_dates.DateFormatter('%H:%M')

#sb.histplot(df_w1824, x = 'Swim Time')
plt.gca().xaxis.set_major_formatter(date_format)

# sns.histplot(df, x='age', bins=np.arange(-0.5, 86, 5), kde=False, hue='survived', legend=True, ax=ax5)
#ax5.legend(['2019', '2021'], title='Race year', prop={'size': 12})
plt.show()

fig = plt.figure(constrained_layout=True, figsize=(8, 3))
#spec = fig.add_gridspec(1, 2)
#ax5 = fig.add_subplot(spec[0, :])
sns.histplot(df_am, x='Bike Time DT', kde=False, bins = 10)
plt.axvline(xmedian_bike, c='red')
plt.axvline(x25_bike, c='red')
plt.axvline(x75_bike, c='red')
date_format = mpl_dates.DateFormatter('%H:%M')

#sb.histplot(df_w1824, x = 'Swim Time')
plt.gca().xaxis.set_major_formatter(date_format)

# sns.histplot(df, x='age', bins=np.arange(-0.5, 86, 5), kde=False, hue='survived', legend=True, ax=ax5)
#ax5.legend(['2019', '2021'], title='Race year', prop={'size': 12})
plt.show()

fig = plt.figure(constrained_layout=True, figsize=(8, 3))
#spec = fig.add_gridspec(1, 2)
#ax5 = fig.add_subplot(spec[0, :])
sns.histplot(df_am, x='Run Time DT', kde=False, bins = 10)
plt.axvline(xmedian_run, c='red')
plt.axvline(x25_run, c='red')
plt.axvline(x75_run, c='red')
date_format = mpl_dates.DateFormatter('%H:%M')

#sb.histplot(df_w1824, x = 'Swim Time')
plt.gca().xaxis.set_major_formatter(date_format)

# sns.histplot(df, x='age', bins=np.arange(-0.5, 86, 5), kde=False, hue='survived', legend=True, ax=ax5)
#ax5.legend(['2019', '2021'], title='Race year', prop={'size': 12})
plt.show()

# %%
palette = {c:'red' if c <= 10 else 'grey' for c in df_long_as.Division_Rank.unique()}

fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.lineplot(data=df_long_as, x='variable', y='value', hue = 'Division_Rank', palette = palette, marker='o', legend = False)
date_format = mpl_dates.DateFormatter('%H:%M')
plt.gca().yaxis.set_major_formatter(date_format)

plt.show()

# %%
# bar graph of the number of years of experience 

sns.countplot(x= 'experience', data = df_am) #why would someone appear 4x? 

#sns.countplot(x="class", data=titanic)
# Out:
# <AxesSubplot:xlabel='experience', ylabel='count'>

# %%
# is swim time a predictor of bike time and run time?, what about total time? Because I am most nervous about the swim

#Look for correlations
corr = df_am.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_f2e6d_row0_col0,#T_f2e6d_row1_col1,#T_f2e6d_row2_col2,#T_f2e6d_row3_col3,#T_f2e6d_row4_col4,#T_f2e6d_row5_col5,#T_f2e6d_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f2e6d_row0_col1{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_f2e6d_row0_col2{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_f2e6d_row0_col3{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_f2e6d_row0_col4{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_f2e6d_row0_col5,#T_f2e6d_row5_col0{
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }#T_f2e6d_row0_col6{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_f2e6d_row1_col0,#T_f2e6d_row1_col2,#T_f2e6d_row1_col6,#T_f2e6d_row6_col1,#T_f2e6d_row6_col3,#T_f2e6d_row6_col4,#T_f2e6d_row6_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_f2e6d_row1_col3{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_f2e6d_row1_col4{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_f2e6d_row1_col5{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_f2e6d_row2_col0{
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }#T_f2e6d_row2_col1{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_f2e6d_row2_col3{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_f2e6d_row2_col4{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_f2e6d_row2_col5{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_f2e6d_row2_col6{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_f2e6d_row3_col0{
#             background-color:  #e16751;
#             color:  #000000;
#         }#T_f2e6d_row3_col1{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_f2e6d_row3_col2{
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }#T_f2e6d_row3_col4{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_f2e6d_row3_col5{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_f2e6d_row3_col6{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_f2e6d_row4_col0{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_f2e6d_row4_col1{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_f2e6d_row4_col2{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_f2e6d_row4_col3{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_f2e6d_row4_col5,#T_f2e6d_row5_col4{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_f2e6d_row4_col6{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_f2e6d_row5_col1{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_f2e6d_row5_col2{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_f2e6d_row5_col3{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_f2e6d_row5_col6{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_f2e6d_row6_col0{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_f2e6d_row6_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }</style><table id="T_f2e6d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Overall Rank</th>        <th class="col_heading level0 col1" >Year</th>        <th class="col_heading level0 col2" >Swim Time Obj</th>        <th class="col_heading level0 col3" >Bike Time Obj</th>        <th class="col_heading level0 col4" >Run Time Obj</th>        <th class="col_heading level0 col5" >Total Time Obj</th>        <th class="col_heading level0 col6" >experience</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2e6d_level0_row0" class="row_heading level0 row0" >Overall Rank</th>
#                         <td id="T_f2e6d_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_f2e6d_row0_col1" class="data row0 col1" >-0.202536</td>
#                         <td id="T_f2e6d_row0_col2" class="data row0 col2" >0.643224</td>
#                         <td id="T_f2e6d_row0_col3" class="data row0 col3" >0.831980</td>
#                         <td id="T_f2e6d_row0_col4" class="data row0 col4" >0.820993</td>
#                         <td id="T_f2e6d_row0_col5" class="data row0 col5" >0.937919</td>
#                         <td id="T_f2e6d_row0_col6" class="data row0 col6" >0.049054</td>
#             </tr>
#             <tr>
#                         <th id="T_f2e6d_level0_row1" class="row_heading level0 row1" >Year</th>
#                         <td id="T_f2e6d_row1_col0" class="data row1 col0" >-0.202536</td>
#                         <td id="T_f2e6d_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_f2e6d_row1_col2" class="data row1 col2" >-0.082362</td>
#                         <td id="T_f2e6d_row1_col3" class="data row1 col3" >0.065185</td>
#                         <td id="T_f2e6d_row1_col4" class="data row1 col4" >0.135199</td>
#                         <td id="T_f2e6d_row1_col5" class="data row1 col5" >0.084528</td>
#                         <td id="T_f2e6d_row1_col6" class="data row1 col6" >-0.601326</td>
#             </tr>
#             <tr>
#                         <th id="T_f2e6d_level0_row2" class="row_heading level0 row2" >Swim Time Obj</th>
#                         <td id="T_f2e6d_row2_col0" class="data row2 col0" >0.643224</td>
#                         <td id="T_f2e6d_row2_col1" class="data row2 col1" >-0.082362</td>
#                         <td id="T_f2e6d_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_f2e6d_row2_col3" class="data row2 col3" >0.529383</td>
#                         <td id="T_f2e6d_row2_col4" class="data row2 col4" >0.421933</td>
#                         <td id="T_f2e6d_row2_col5" class="data row2 col5" >0.637093</td>
#                         <td id="T_f2e6d_row2_col6" class="data row2 col6" >-0.013568</td>
#             </tr>
#             <tr>
#                         <th id="T_f2e6d_level0_row3" class="row_heading level0 row3" >Bike Time Obj</th>
#                         <td id="T_f2e6d_row3_col0" class="data row3 col0" >0.831980</td>
#                         <td id="T_f2e6d_row3_col1" class="data row3 col1" >0.065185</td>
#                         <td id="T_f2e6d_row3_col2" class="data row3 col2" >0.529383</td>
#                         <td id="T_f2e6d_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_f2e6d_row3_col4" class="data row3 col4" >0.625959</td>
#                         <td id="T_f2e6d_row3_col5" class="data row3 col5" >0.887778</td>
#                         <td id="T_f2e6d_row3_col6" class="data row3 col6" >-0.140411</td>
#             </tr>
#             <tr>
#                         <th id="T_f2e6d_level0_row4" class="row_heading level0 row4" >Run Time Obj</th>
#                         <td id="T_f2e6d_row4_col0" class="data row4 col0" >0.820993</td>
#                         <td id="T_f2e6d_row4_col1" class="data row4 col1" >0.135199</td>
#                         <td id="T_f2e6d_row4_col2" class="data row4 col2" >0.421933</td>
#                         <td id="T_f2e6d_row4_col3" class="data row4 col3" >0.625959</td>
#                         <td id="T_f2e6d_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_f2e6d_row4_col5" class="data row4 col5" >0.892752</td>
#                         <td id="T
